# %% [markdown]
# ##   Intoductory Python for Machine learning Quiz Solution

# %%
import pandas as pd

# %%
food=pd.read_csv("FoodBalanceSheets_E_Africa_NOFLAG.csv",encoding="latin1")

# %%
food.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
#11
food.groupby("Item")[["Item","Y2014","Y2017"]].sum().loc["Animal fats"]
# Out:
# Y2014    209460.54
# Y2017    269617.53
# Name: Animal fats, dtype: float64

# %%
#12
food.describe().loc[["mean","std"],["Y2015"]]
# Out:
#             Y2015
# mean   135.235966
# std   1603.403984

# %%
#13
food["Y2016"].isnull().sum()
# Out:
# 1535

# %%
#14
food.corr().iloc[2,3:].sort_values(ascending=False).head(1)
# Out:
# Y2014    0.024457
# Name: Element Code, dtype: float64

# %%
#15
food.groupby("Element").sum().loc["Import Quantity"].iloc[3:].sort_values(ascending=False).head(1)
# Out:
# Y2017    294559.09
# Name: Import Quantity, dtype: float64

# %%
#16
food.groupby("Element").sum().loc["Production","Y2014"]
# Out:
# 1931287.7500000005

# %%
#17
food.groupby("Element")["Y2018"].sum().sort_values(ascending=False).head(1)
# Out:
# Element
# Domestic supply quantity    2161192.1
# Name: Y2018, dtype: float64

# %%
#18
food.groupby("Element")["Y2018"].sum().sort_values().head(3).index[2]
# Out:
# 'Protein supply quantity (g/capita/day)'

# %%
#19
food.groupby(["Area","Element"]).sum().loc["Algeria","Y2018"]["Import Quantity"]
# Out:
# 36238.29

# %%
#20
food["Area"].nunique()
# Out:
# 49
